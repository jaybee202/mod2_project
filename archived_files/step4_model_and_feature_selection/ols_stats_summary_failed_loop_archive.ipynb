# %% [markdown]
# Links from Marisa:
#
# RFE: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html#sklearn.feature_selection.RFE
#
# OHE options: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html

# %% [markdown]
# ### Import the required packages

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import matplotlib.pyplot as plt 
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
import sklearn.preprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from scipy.stats import stats

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Function to loop ols iterations, will be run later on...

# %%
def ols_run(X, y, run):
    Xconst = sm.add_constant(X)
    
    ols_model = sm.OLS(y, Xconst, hasconst= True)
    est = ols_model.fit()
    
    results_as_html = results.tables[1].as_html()
    ols_df = pd.read_html(results_as_html, header=0, index_col=0)[0]
    ols_df = ols_df.reset_index()
    ols_df = ols_df.rename(columns={'index':'feature'});

    kill_cols = ols_df['feature'][(ols_df['t'] > -1) & (ols_df['t'] < 1)]
    
    sum_residuals = sum(est.resid) - sum(y_train)
    r2_adj = est.rsquared_adj

    run_dict = {'ols_run': run, \
                'sum_resid': sum_residuals, \
                'r2_adj': r2_adj, \
                'cols': Xconst.shape[1] - 1,\
                'kill_cols': kill_cols.shape}
    run_df = pd.DataFrame.from_dict([run_dict])
    
    return [kill_cols, run_df]

# %% [markdown]
# ### Import the data and create X df for independant variables and y df for dependant variables

# %%
data = pd.read_csv('data_cleaned.csv', index_col=0)
data = data.drop(columns=['id', 'long', 'lat', 'date'])
X_cols = data.drop(columns=['price'])
y = data.price.values

# %% [markdown]
# ### Review histogram from the dependant variables

# %%
# pd.DataFrame.hist(X_cols, figsize = [15,15]);

# residuals of overall model are important not normality of variables

# %% [markdown]
# ### Prepare data for the one hot encoding and column transformation
# Need to create data frame and lists of categorical variables and continuous variables

# %%
categories = X_cols[['bathrooms', 'bedrooms', 'floors', 'condition', 'grade', 'attic', \
                     'zipcode', 'view', 'yr_built']]
categories_ls = list(categories.columns)
x_cols_ls = list(X_cols.columns)
numeric_vars = [x for x in x_cols_ls if x not in categories]

# %% [markdown]
# ### Create a minimum/maximum value dictionary
# This dictionary records the minimum/maximum values for the continuous, independant variables to return to normal values after normalization.  Convert the dicitonary to a dataframe and save as a csv.

# %%
# min_max_dict = {}

# for c in X_cols:
#     if c in categories.columns:
#         pass
#     else:
#         min_max_dict.update({c: [X_cols[c].min(), X_cols[c].max()]})

# min_max_df = pd.DataFrame.from_dict(min_max_dict)
# min_max_df.to_csv('min_max_vals')

# %%
### Create ohe headers (based on categorical values) and continuous variable headers

# %% [markdown]
# ### Min/max scaling for independant, continuous variables and convert categorical variables to strings

# %%
# Create dictionary of category variable names, counts, and a sorted list of values
category_counts = {}

for cat in categories:
    l = len(list(X_cols[cat].unique())) - 1
    vals = sorted(list(X_cols[cat].unique().round(3)))
    category_counts.update({cat: [l, vals[1:]]})

ohe_cols = []
for cc in category_counts:
    for r in range(0, category_counts[cc][0]):
        column = '{}_{}'.format(cc, category_counts[cc][1][r])
        ohe_cols.append(column)

# %%
min_max_scaler = sklearn.preprocessing.MinMaxScaler()

for c in X_cols.columns:
    if c in categories:
        X_cols[c] = X_cols[c].astype(str)
    else:
        x = np.array(X_cols[c]).reshape(-1, 1)
        X_cols[c] = min_max_scaler.fit_transform(x)

# %% [markdown]
# ### One hot encoding for housing data

# %%
## create an encoder object. This will help us to convert
## categorical variables to new columns
encoder = OneHotEncoder(handle_unknown= 'error',
                        drop='first',
                        categories= 'auto',
                        sparse=True)

## Create an columntransformer object.
## This will help us to merge transformed columns
## with the rest of the dataset.

ct = ColumnTransformer(transformers =[('ohe', encoder, categories_ls)], remainder= 'passthrough')
ct.fit(X_cols[x_cols_ls])
X = ct.transform(X_cols)
X = X.todense()

# %%
# Create columns for X df
columns = ohe_cols + numeric_vars

# %%
X = pd.DataFrame(X, columns=columns)

# %% [markdown]
# ### Split data into train and test groups

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

X_train.to_csv('X_train.csv')

# %%
import pickle
pickle_out = open('y_train.pickle','wb')
pickle.dump(y_train, pickle_out)
pickle_out.close()

# %% [markdown]
# ### Loop OLS Sumary data tracking r2 adjusted, total residual value, total columns, and run number

# %%
run1 = ols_run(X_train, y_train, 1)
X_train_chop = X_train.drop(columns=run1[0])
ols_df = run1[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-4c028c1f5c95> in <module>
# ----> 1 run1 = ols_run(X_train, y_train, 1)
#       2 X_train_chop = X_train.drop(columns=run1[0])
#       3 ols_df = run1[1]
#
# <ipython-input-8-47de29a821b5> in ols_run(X, y, run)
#       5     est = ols_model.fit()
#       6
# ----> 7     results_as_html = results.tables[1].as_html()
#       8     ols_df = pd.read_html(results_as_html, header=0, index_col=0)[0]
#       9     ols_df = ols_df.reset_index()
#
# NameError: name 'results' is not defined

# %%
for run in range(2, 100):
    ols_data = ols_run(X_train_chop, y_train, run)
    ols_df = pd.concat([ols_df, ols_data[1]], axis=0)
    X_train_chop = X_train.drop(columns=ols_data[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b5a06f6a153f> in <module>
#       1 for run in range(2, 100):
# ----> 2     ols_data = ols_run(X_train_chop, y_train, run)
#       3     ols_df = pd.concat([ols_df, ols_data[1]], axis=0)
#       4     X_train_chop = X_train.drop(columns=ols_data[0])
#
# NameError: name 'X_train_chop' is not defined

# %%
# ols_df

# %%
# run = ols_run(X_train_chop, y_train, 2, ols_df)
# ols_df = pd.concat([ols_df, run[1]], axis=0)
# ols_df

# %% [markdown]
# ### Code for a one-time OLS stats model summary, used to populate the function and loop above

# %%
Xconst = sm.add_constant(X_train)

ols_model = sm.OLS(y_train, Xconst, hasconst= True)
est = ols_model.fit()
est.summary()

results = est.summary();
results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     325.7
# Date:                Tue, 24 Mar 2020   Prob (F-statistic):               0.00
# Time:                        21:20:06   Log-Likelihood:            -2.1518e+05
# No. Observations:               16149   AIC:                         4.309e+05
# Df Residuals:                   15898   BIC:                         4.328e+05
# Df Model:                         250
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.363e+05   1.16e+05      1.178      0.239   -9.05e+04    3.63e+05
# bathrooms_0.75 -2.272e+04   1.09e+05     -0.209      0.834   -2.36e+05     1.9e+05
# bathrooms_1.0    532.7872   1.06e+05      0.005      0.996   -2.08e+05    2.09e+05
# bathrooms_1.25 -1.309e+05   1.23e+05     -1.067      0.286   -3.72e+05     1.1e+05
# yr_built_2007  -4.679e+04   2.19e+04     -2.134      0.033   -8.98e+04   -3816.640
# yr_built_2008  -3.873e+04   2.23e+04     -1.740      0.082   -8.24e+04    4908.383
# yr_built_2009  -2.404e+04   2.32e+04     -1.036      0.300   -6.95e+04    2.14e+04
# yr_built_2010  -3233.7513    2.5e+04     -0.130      0.897   -5.21e+04    4.57e+04
# yr_built_2011  -1.648e+04   2.53e+04     -0.652      0.514    -6.6e+04     3.3e+04
# yr_built_2012  -2.522e+04   2.42e+04     -1.041      0.298   -7.27e+04    2.23e+04
# yr_built_2013   1.456e+04   2.37e+04      0.613      0.540    -3.2e+04    6.11e+04
# yr_built_2014    457.3560   2.16e+04      0.021      0.983   -4.19e+04    4.28e+04
# yr_built_2015  -4.275e+04   3.47e+04     -1.231      0.218   -1.11e+05    2.53e+04
# sqft_living     1.086e+06   2.11e+05      5.147      0.000    6.73e+05     1.5e+06
# sqft_lot        4.026e+05   7.19e+04      5.598      0.000    2.62e+05    5.44e+05
# sqft_above      6.796e+05   1.46e+05      4.657      0.000    3.94e+05    9.66e+05
# sqft_basement   1.607e+05   7.67e+04      2.094      0.036    1.02e+04    3.11e+05
# sqft_living15   1.075e+05   1.86e+04      5.776      0.000     7.1e+04    1.44e+05
# sqft_lot15      -1.26e+05   5.86e+04     -2.153      0.031   -2.41e+05   -1.13e+04
# ==============================================================================
# Omnibus:                    13271.129   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2657494.269
# Skew:                           3.135   Prob(JB):                         0.00
# Kurtosis:                      65.531   Cond. No.                     2.65e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.04e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
results_as_html = results.tables[1].as_html()
ols_df = pd.read_html(results_as_html, header=0, index_col=0)[0]
ols_df = ols_df.reset_index()
ols_df = ols_df.rename(columns={'index':'feature'});
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-16e329f0e402> in <module>
# ----> 1 results_as_html = results.tables[1].as_html()
#       2 ols_df = pd.read_html(results_as_html, header=0, index_col=0)[0]
#       3 ols_df = ols_df.reset_index()
#       4 ols_df = ols_df.rename(columns={'index':'feature'});
#
# NameError: name 'results' is not defined

# %%
pd.set_option('display.max_rows', None)
ols_df.sort_values(by='t', ascending=False)

kill_cols = ols_df['feature'][(ols_df['t'] > -1) & (ols_df['t'] < 1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c9f268c21e7b> in <module>
# ----> 1 pd.set_option('display.max_rows', None)
#       2 ols_df.sort_values(by='t', ascending=False)
#       3
#       4 kill_cols = ols_df['feature'][(ols_df['t'] > -1) & (ols_df['t'] < 1)]
#
# NameError: name 'pd' is not defined

# %%
sum_residuals = sum(est.resid) - sum(y_train)
r2_adj = est.rsquared_adj

ols_dict = {'ols_run': 1, 'sum_resid': sum_residuals, 'r2_adj': r2_adj, 'cols': Xconst.shape[1] - 1}
ols_df = pd.DataFrame.from_dict([ols_dict])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b4568f4801ff> in <module>
# ----> 1 sum_residuals = sum(est.resid) - sum(y_train)
#       2 r2_adj = est.rsquared_adj
#       3
#       4 ols_dict = {'ols_run': 1, 'sum_resid': sum_residuals, 'r2_adj': r2_adj, 'cols': Xconst.shape[1] - 1}
#       5 ols_df = pd.DataFrame.from_dict([ols_dict])
#
# NameError: name 'est' is not defined

# %%
ols_df
# Out:
#    ols_run     sum_resid    r2_adj  cols
# 0        1 -8.754851e+09  0.834061   252

# %%
X_train_chop = X_train.drop(columns=kill_cols)

# %%
X_train_chop.shape == X_train.shape
# Out:
# False

# %%
ols_run(X_train_chop, y_train, 2)
# Out:
# [1      bathrooms_0.75
#  2       bathrooms_1.0
#  4       bathrooms_1.5
#  5      bathrooms_1.75
#  6       bathrooms_2.0
#  7      bathrooms_2.25
#  8       bathrooms_2.5
#  9      bathrooms_2.75
#  10      bathrooms_3.0
#  11     bathrooms_3.25
#  12      bathrooms_3.5
#  13     bathrooms_3.75
#  14      bathrooms_4.0
#  24      bathrooms_6.5
#  26      bathrooms_7.5
#  30         bedrooms_3
#  31         bedrooms_4
#  32         bedrooms_5
#  33         bedrooms_6
#  39         floors_1.5
#  43         floors_3.5
#  58            attic_1
#  59      zipcode_98002
#  60      zipcode_98003
#  70      zipcode_98022
#  76      zipcode_98030
#  78      zipcode_98032
#  84      zipcode_98042
#  126     zipcode_98198
#  135     yr_built_1904
#  137     yr_built_1906
#  139     yr_built_1908
#  140     yr_built_1909
#  141     yr_built_1910
#  142     yr_built_1911
#  143     yr_built_1912
#  145     yr_built_1914
#  146     yr_built_1915
#  147     yr_built_1916
#  148     yr_built_1917
#  150     yr_built_1919
#  151     yr_built_1920
#  152     yr_built_1921
#  153     yr_built_1922
#  154     yr_built_1923
#  155     yr_built_1924
#  156     yr_built_1925
#  157     yr_built_1926
#  158     yr_built_1927
#  160     yr_built_1929
#  161     yr_built_1930
#  163     yr_built_1932
#  165     yr_built_1934
#  166     yr_built_1935
#  168     yr_built_1937
#  169     yr_built_1938
#  170     yr_built_1939
#  172     yr_built_1941
#  173     yr_built_1942
#  174     yr_built_1943
#  175     yr_built_1944
#  176     yr_built_1945
#  180     yr_built_1949
#  181     yr_built_1950
#  182     yr_built_1951
#  188     yr_built_1957
#  200     yr_built_1969
#  212     yr_built_1981
#  214     yr_built_1983
#  230     yr_built_1999
#  241     yr_built_2010
#  242     yr_built_2011
#  244     yr_built_2013
#  245     yr_built_2014
#  Name: feature, dtype: object,
#     ols_run     sum_resid   r2_adj  cols kill_cols
#  0        2 -8.754851e+09  0.83262   178     (74,)]

# %% [markdown]
# ### Loop ols regressions

# %%
def ols_run(X, y, run):
    Xconst = sm.add_constant(X)
    
    ols_model = sm.OLS(y, Xconst, hasconst= True)
    est = ols_model.fit()
    
    results_as_html = results.tables[1].as_html()
    ols_df = pd.read_html(results_as_html, header=0, index_col=0)[0]
    ols_df = ols_df.reset_index()
    ols_df = ols_df.rename(columns={'index':'feature'});

    kill_cols = ols_df['feature'][(ols_df['t'] > -1) & (ols_df['t'] < 1)]
    
    sum_residuals = sum(est.resid) - sum(y_train)
    r2_adj = est.rsquared_adj

    run_dict = {'ols_run': run, 'sum_resid': sum_residuals, 'r2_adj': r2_adj, 'cols': Xconst.shape[1] - 1}
    run_df = pd.DataFrame.from_dict([run_dict])
    
    return [kill_cols, run_df]
